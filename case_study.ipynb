# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt 
import seaborn as sns

# %% [markdown]
# # 1:reading the data

# %%
cars=pd.read_csv('cars_data.csv')

# %%
cars
# Out:
#          Make        Model    Nickname Car Gender Buyer Gender  Buyer Age  \
# 0      Suzuki       Vitara  Philippine     Female       Female         51
# 1       Honda        S2000      Henrik       Male         Male         30
# 2         BMW           Z4      Lebbie       Male       Female         54
# 3      Toyota       Tacoma    Jefferey     Female         Male         68
# 4        Ford      Festiva     Glendon     Female         Male         70
# ...       ...          ...         ...        ...          ...        ...
# 9995    Mazda      Tribute      Cooper       Male         Male         44
# 9996      GMC  Sierra 2500         Dud       Male         Male         40
# 9997  Mercury      Mariner     Chariot       Male         Male         37
# 9998   Daewoo      Leganza       Dynah     Female       Female         21
# 9999   Toyota      Sequoia    Zedekiah     Female         Male         21
#
#            Buzzword      Country             City  Dealer Latitude  \
# ...

# %% [markdown]
# # 2:null values

# %%
cars.isna().sum()
# Out:
# Make                 0
# Model                0
# Nickname             0
# Car Gender           0
# Buyer Gender         0
# Buyer Age            0
# Buzzword             0
# Country              0
# City                 0
# Dealer Latitude      0
# Dealer Longitude     0
# Color                0
# New Car              0
# Purchase Date        0
# Sale Price           0
# Discount             0
# Resell Price         0
# 5-yr Depreciation    0
# Top Speed            0
# 0-60 Time            0
# dtype: int64

# %% [markdown]
# # 3: bar graph

# %%
plt.figure()
plt.hist(cars['Buyer Gender'],color='grey',)
plt.title('display of buyers on gender basis ',fontsize=15)
plt.xticks()
plt.yticks()
plt.xlabel('gender',fontsize=10)
plt.ylabel('no of sales',fontsize=10,rotation=90)

# %%
df1=cars[cars['Sale Price']>70000]

# %%
df1
# Out:
#                Make        Model  Nickname Car Gender Buyer Gender  Buyer Age  \
# 2               BMW           Z4    Lebbie       Male       Female         54
# 4              Ford      Festiva   Glendon     Female         Male         70
# 10           Toyota       Previa     Winni     Female       Female         67
# 11            Scion           xB     Arlie       Male       Female         29
# 12          Porsche          928   Celesta     Female       Female         37
# ...             ...          ...       ...        ...          ...        ...
# 9985           Ford       Bronco      Cara     Female       Female         42
# 9992  Mercedes-Benz      R-Class     Stace     Female       Female         20
# 9996            GMC  Sierra 2500       Dud       Male         Male         40
# 9998         Daewoo      Leganza     Dynah     Female       Female         21
# 9999         Toyota      Sequoia  Zedekiah     Female         Male         21
#
# ...

# %%
descend=df1.sort_values('Sale Price',ascending=False)

# %%
descend
# Out:
#             Make        Model   Nickname Car Gender Buyer Gender  Buyer Age  \
# 5984  Volkswagen    Jetta III    Rachael     Female       Female         73
# 1270        Audi           A6      Thorn       Male         Male         75
# 3460       Lexus           LX      Aldin     Female         Male         38
# 9032       Mazda         MX-6  Sylvester     Female         Male         26
# 302        Lexus           ES       Brig     Female         Male         39
# ...          ...          ...        ...        ...          ...        ...
# 5350       Buick        Regal      Derek     Female         Male         45
# 8024   Chevrolet      Venture     Darryl     Female         Male         65
# 465          GMC  Sierra 1500    Bernarr     Female         Male         45
# 5533     Pontiac   Bonneville    Silvana       Male       Female         46
# 5275         Kia      Sorento      Udall       Male         Male         49
#
# ...

# %% [markdown]
# #  4:Top 5 car based on sales

# %%
df2=descend[descend['Sale Price']>99973]

# %%
df2
# Out:
#             Make      Model   Nickname Car Gender Buyer Gender  Buyer Age  \
# 5984  Volkswagen  Jetta III    Rachael     Female       Female         73
# 1270        Audi         A6      Thorn       Male         Male         75
# 3460       Lexus         LX      Aldin     Female         Male         38
# 9032       Mazda       MX-6  Sylvester     Female         Male         26
# 302        Lexus         ES       Brig     Female         Male         39
#
#                Buzzword   Country           City  Dealer Latitude  \
# 5984               core    Russia    Krasnoyarka        59.418208
# 1270           function    Latvia        Līgatne        57.236340
# 3460           software  Malaysia      Pasir Mas         6.109065
# 9032  internet solution    Russia  Krutaya Gorka        55.369917
# 302         user-facing    Canada       Langford        48.447463
#
#       Dealer Longitude   Color  New Car Purchase Date  Sale Price  Discount  \
# ...

# %% [markdown]
# # 5:Least 5 cars based on sales

# %%
df3=descend[descend['Sale Price']<70026]

# %%
df3
# Out:
#            Make        Model Nickname Car Gender Buyer Gender  Buyer Age  \
# 5350      Buick        Regal    Derek     Female         Male         45
# 8024  Chevrolet      Venture   Darryl     Female         Male         65
# 465         GMC  Sierra 1500  Bernarr     Female         Male         45
# 5533    Pontiac   Bonneville  Silvana       Male       Female         46
# 5275        Kia      Sorento    Udall       Male         Male         49
#
#             Buzzword      Country         City  Dealer Latitude  \
# 5350        Optional  Philippines  San Antonio        14.550887
# 8024  info-mediaries        China       Hengxi        36.628305
# 465         Expanded       Sweden     Göteborg        57.731461
# 5533    User-centric        China    Jiucaigou        36.730406
# 5275       maximized        China       Jinsha        30.679359
#
#       Dealer Longitude       Color  New Car Purchase Date  Sale Price  \
# ...
